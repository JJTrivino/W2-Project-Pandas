# %%
from IPython.display import Image

# %% [markdown]
# # Are sharks dangerous?

# %%
Image("images/Portada.jpeg")

# %% [markdown]
# - A shark attack is an assault on a human being by a shark. Every year, a certain number of people are attacked by sharks, although these attacks are not usually fatal.

# %%
Image("images/Attacks in the history.jpeg")

# %% [markdown]
# The graph above shows a large increase in shark attacks in recent years.

# %% [markdown]
# ## Should we be concerned?

# %%
Image("images/Dangersharks.jpeg")

# %% [markdown]
# ## We are more likely to be struck by lightning on a cloudy afternoon than attacked by a shark.

# %%
Image("images/Fatality.jpeg")

# %% [markdown]
# ## But if we were attacked by a shark, there is a good chance that we would get out alive.

# %% [markdown]
# ### Here we show you where shark attacks occur most frequently.

# %%
Image("images/Countries_attacks.jpeg")

# %% [markdown]
# ## Hypothesis: What is the activity with the highest risk of shark attacks?

# %% [markdown]
# ### indeed the most dangerous activity is surfing  followed by swimming.

# %%
Image("images/Activities.jpeg")

# %% [markdown]
# ## But what I found most surprising is the number of attacks categorized as "provoked". The probability of being attacked by a shark is low but don't challenge them!

# %%
Image("images/provoked_unprovoked.jpeg")

# %% [markdown]
# ## About 2000 of the 5000 cases were provoked!
